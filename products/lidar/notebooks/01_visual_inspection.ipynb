# %% [markdown]
# # 01 Visual Inspection
#
# Skeleton notebook -- logic lives in the `lidar_core`/`lidar_io`/`lidar_volume` packages, not here.

# %%
# TODO: fill in with a real dataset path once available.
